# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\rajat shukla\anaconda3\lib\site-packages (4.4.3)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\rajat shukla\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\rajat shukla\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio~=0.17 in c:\users\rajat shukla\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\rajat shukla\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: sniffio in c:\users\rajat shukla\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\rajat shukla\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: idna in c:\users\rajat shukla\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: outcome in c:\users\rajat shukla\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\rajat shukla\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\rajat shukla\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\rajat shukla\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: pycparser in c:\users\rajat shukla\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\rajat shukla\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\rajat shukla\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\rajat shukla\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver= webdriver.Chrome(r"C:\Users\Rajat Shukla\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      70             cmd.extend(self.command_line_args())
# ---> 71             self.process = subprocess.Popen(cmd, env=self.env,
#      72                                             close_fds=system() != 'Windows',
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# C:\Users\RAJATS~1\AppData\Local\Temp/ipykernel_16116/191662975.py in <module>
# ----> 1 driver=webdriver.Chrome(r"chromedriver.exe")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67             service = Service(executable_path, port, service_args, service_log_path)
#      68
# ---> 69         super().__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      70                          port, options,
#      71                          service_args, desired_capabilities,
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chromium\webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      87
#      88         self.service = service
# ---> 89         self.service.start()
#      90
#      91         try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      79         except OSError as err:
#      80             if err.errno == errno.ENOENT:
# ---> 81                 raise WebDriverException(
#      82                     "'{}' executable needs to be in PATH. {}".format(
#      83                         os.path.basename(self.path), self.start_error_message)
#
# WebDriverException: Message: 'chromedriver.exe' executable needs to be in PATH. Please see https://chromedriver.chromium.org/home

# %% [markdown]
# # Question 1&2

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
loction=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
loction.send_keys('Banglore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_loction=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
loction_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loction_tags[0:10]:
    loction=i.text
    job_loction.append(loction)

# %%
print(len(job_title),len(job_loction))
# Out:
# 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_loction})
df
# Out:
#                                                Title  \
# 0                                Senior Data Analyst
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3                        Data Analyst - CRM Platform
# 4                                       Data Analyst
# 5  Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 6  Call For Clinical Data Analyst - Hyd/Bangalore...
# 7                Payroll Transformation Data Analyst
# 8                Payroll Transformation Data Analyst
# 9            Master Data Management Business Analyst
#
#                                             Location
# 0                       Chennai, Bangalore/Bengaluru
# 1  Mangaluru/Mangalore, Pune, Bangalore/Bengaluru...
# 2                                Bangalore/Bengaluru
# 3  Mumbai, Hyderabad/Secunderabad, Pune, Chennai,...
# 4                                Bangalore/Bengaluru
# 5  Kolkata, Hyderabad/Secunderabad, Pune, Bangalo...
# 6  Kolkata, Hyderabad/Secunderabad, Pune, Bangalo...
# 7                                Bangalore/Bengaluru
# 8                                Bangalore/Bengaluru
# 9                                Bangalore/Bengaluru

# %% [markdown]
# # Question 3

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
loction=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
loction.send_keys('Banglore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_loction=[]
company_name=[]
experiance_required=[]
salary_amount=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
loction_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loction_tags[0:10]:
    loction=i.text
    job_loction.append(loction)
    
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
    
experiance_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in experiance_tags[0:10]:
    experiance=i.text
    experiance_required.append(experiance)

# %%
salary_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi salary"]')
for i in salary_tags[0:10]:
    salary=i.text
    salary_amount.append(salary)

# %%
print(len(job_title),len(job_loction),len(company_name),len(experiance_required),len(salary_amount))
# Out:
# 10 10 10 10 10

# %%
df=pd.DataFrame({'Job Title':job_title,'Job Location':job_loction,'Company Name':company_name,'Experiance':experiance_required,'Salary':salary_amount})
df
# Out:
#                                            Job Title  \
# 0  Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 1  Call For Clinical Data Analyst - Hyd/Bangalore...
# 2                                       Data Analyst
# 3                                       Data Analyst
# 4                                       Data Analyst
# 5            Master Data Management Business Analyst
# 6  Data Analytics and Interpretation Business Ana...
# 7                                Senior Data Analyst
# 8                                    HR Data Analyst
# 9                                       Data Analyst
#
#                                         Job Location  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Bangalo...
# 1  Kolkata, Hyderabad/Secunderabad, Pune, Bangalo...
# 2                                Bangalore/Bengaluru
# 3  Mangaluru/Mangalore, Pune, Bangalore/Bengaluru...
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7                       Chennai, Bangalore/Bengaluru
# 8                                Bangalore/Bengaluru
# 9                                Bangalore/Bengaluru
#
#                Company Name Experiance                   Salary
# 0                 Cognizant    3-8 Yrs            Not disclosed
# 1                 Cognizant    6-9 Yrs            Not disclosed
# 2                       Jar    0-4 Yrs  4,00,000 - 9,00,000 PA.
# 3  Coresight Research, Inc.    4-8 Yrs            Not disclosed
# 4                    Varite    2-5 Yrs            Not disclosed
# 5                 Accenture    6-8 Yrs            Not disclosed
# 6                 Accenture    6-8 Yrs            Not disclosed
# 7                Latentview    3-6 Yrs            Not disclosed
# 8              Hitachi Ltd.    3-6 Yrs            Not disclosed
# 9                       ANZ   7-12 Yrs            Not disclosed

# %% [markdown]
# # Question 4

# %%
driver.get("http://www.flipkart.com/")

# %%
product=driver.find_element(By.XPATH,"/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
product.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand_name=[]
product_desp=[]
price_amount=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=i.text
    brand_name.append(brand)
    
product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags[0:100]:
    product=i.text
    product_desp.append(product)
    
price_tags=driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price_tags[0:100]:
    price=i.text
    price_amount.append(price)

# %%
print(len(brand_name),len(product_tags),len(price_tags))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'Brand':brand_name,'Product':product_desp,'Price':price_amount})
df
# Out:
#                 Brand                                            Product  \
# 0      ROZZETTA CRAFT              UV Protection Aviator Sunglasses (55)
# 1      ROZZETTA CRAFT  UV Protection, Gradient Round Sunglasses (Free...
# 2            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3             DEIXELS  Polarized, UV Protection, Riding Glasses Wayfa...
# 4   SHAAH COLLECTIONS                UV Protection Round Sunglasses (54)
# 5              SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...
# 6   SHAAH COLLECTIONS   UV Protection, Mirrored Wayfarer Sunglasses (54)
# 7      ROZZETTA CRAFT  UV Protection, Gradient Retro Square Sunglasse...
# 8               NuVew              UV Protection Aviator Sunglasses (57)
# 9          LIZA ANGEL      UV Protection Wayfarer Sunglasses (Free Size)
# 10             PIRASO              UV Protection Aviator Sunglasses (54)
# 11             GANSTA    Gradient, UV Protection Aviator Sunglasses (57)
# 12     kingsunglasses   UV Protection Rectangular Sunglasses (Free Size)
# 13  SHAAH COLLECTIONS   UV Protection, Mirrored Wayfarer Sunglasses (54)
# 14  SHAAH COLLECTIONS              UV Protection Aviator Sunglasses (54)
# 15              NuVew              UV Protection Cat-eye Sunglasses (56)
# 16               MODE       UV Protection Aviator Sunglasses (Free Size)
# 17             PIRASO              UV Protection Aviator Sunglasses (58)
# 18      VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...
# 19          ROYAL SON  Polarized, UV Protection Retro Square Sunglass...
# 20          New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 21             PIRASO          UV Protection Rectangular Sunglasses (52)
# 22  SHAAH COLLECTIONS   UV Protection Rectangular Sunglasses (Free Size)
# 23             AISLIN  UV Protection, Gradient Retro Square Sunglasse...
# 24              NuVew   UV Protection, Mirrored Wayfarer Sunglasses (57)
# 25          ROYAL SON   Polarized, UV Protection Aviator Sunglasses (58)
# 26              NuVew    UV Protection, Mirrored Aviator Sunglasses (57)
# 27          ROYAL SON     Polarized, UV Protection Round Sunglasses (52)
# 28           Fastrack        UV Protection Shield Sunglasses (Free Size)
# 29             Sewell  Mirrored, Night Vision, UV Protection, Riding ...
# 30      VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...
# 31          ROYAL SON  Polarized, UV Protection Wayfarer, Retro Squar...
# 32           Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 33           Fastrack              UV Protection Aviator Sunglasses (58)
# 34           Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 35          ROYAL SON  Polarized, UV Protection Retro Square Sunglass...
# 36           Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 37  SHAAH COLLECTIONS                UV Protection Round Sunglasses (52)
# 38           Fastrack   UV Protection Wrap-around Sunglasses (Free Size)
# 39          ROYAL SON  Polarized, UV Protection Wrap-around Sunglasse...
#
#                                  Price
# 0                    ₹649₹2,55574% off
# 1     ₹399₹1,99980% off\nFree delivery
# 2       ₹799₹99920% off\nFree delivery
# 3       ₹249₹59958% off\nFree delivery
# 4     ₹179₹1,29986% off\nFree delivery
# 5     ₹283₹1,29978% off\nFree delivery
# 6     ₹179₹1,29986% off\nFree delivery
# 7     ₹349₹1,99982% off\nFree delivery
# 8       ₹198₹75073% off\nFree delivery
# 9       ₹199₹39950% off\nFree delivery
# 10    ₹237₹1,59985% off\nFree delivery
# 11    ₹272₹1,99986% off\nFree delivery
# 12      ₹199₹99980% off\nFree delivery
# 13    ₹179₹1,29986% off\nFree delivery
# 14      ₹179₹99982% off\nFree delivery
# 15    ₹425₹1,72575% off\nFree delivery
# 16      ₹179₹78377% off\nFree delivery
# 17    ₹305₹2,59988% off\nFree delivery
# 18    ₹599₹1,99970% off\nFree delivery
# 19    ₹486₹1,99975% off\nFree delivery
# 20    ₹264₹2,59989% off\nFree delivery
# 21    ₹246₹1,59984% off\nFree delivery
# 22      ₹179₹99982% off\nFree delivery
# 23    ₹498₹1,52567% off\nFree delivery
# 24      ₹157₹87582% off\nFree delivery
# 25    ₹561₹1,99971% off\nFree delivery
# 26      ₹168₹75077% off\nFree delivery
# 27    ₹599₹1,99970% off\nFree delivery
# 28      ₹719₹89920% off\nFree delivery
# 29    ₹279₹1,49981% off\nFree delivery
# 30    ₹699₹1,99965% off\nFree delivery
# 31    ₹524₹1,99973% off\nFree delivery
# 32      ₹869₹99913% off\nFree delivery
# 33  ₹1,169₹1,29910% off\nFree delivery
# 34      ₹719₹89920% off\nFree delivery
# 35    ₹674₹1,99966% off\nFree delivery
# 36      ₹679₹79915% off\nFree delivery
# 37    ₹179₹1,39987% off\nFree delivery
# 38      ₹719₹89920% off\nFree delivery
# 39    ₹599₹1,99970% off\nFree delivery

# %% [markdown]
# # Question 5

# %%
iphone=driver.find_element(By.CLASS_NAME,"_3704LK")
iphone.send_keys('Iphone 11')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
rating_number=[]
review_summary=[]
full_summary=[]

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=i.text
    rating_number.append(rating)
    
review_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in review_tags[0:100]:
    review=i.text
    review_summary.append(review)
    
full_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in full_tags[0:100]:
    full=i.text
    full_summary.append(full)

# %%
print(len(rating_number),len(review_summary),len(full_summary))
# Out:
# 7 8 8

# %%
df=pd.DataFrame({'Rating':rating_number,'Review':review_summary,'Description':full_summary})
df

# %% [markdown]
# # Question 6

# %%
driver.get('http://www.myntra.com/shoes')

# %%
shoes=driver.find_element(By.CLASS_NAME,"desktop-searchBar")
shoes.send_keys('shoes')

# %%
search=driver.find_element(By.CLASS_NAME,"desktop-submit")
search.click()

# %%
brand_name=[]
product_desp=[]
price_num=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
for i in brand_tags[0:100]:
    brand=i.text
    brand_name.append(brand)
    
    
product_tags=driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
for i in product_tags[0:100]:
    product=i.text
    product_desp.append(product)
    
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="product-price"]')
for i in price_tags[0:100]:
    price=i.text
    price_num.append(price)

# %%
print(len(brand_name),len(product_desp),len(price_num))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'Brand':brand_name,'Product':product_desp,'Price':price_num})
df
# Out:
#               Brand                                     Product  \
# 0   U.S. Polo Assn.                        Men Clarkin Sneakers
# 1          Roadster                                Men Sneakers
# 2          Red Tape                           Men Walking Shoes
# 3   U.S. Polo Assn.                  Men Colourblocked Sneakers
# 4           GRIFFIN                Men Printed Slip-On Sneakers
# ..              ...                                         ...
# 95         Skechers                   Men Go Walk Walking Shoes
# 96         Red Tape                           Men Running Shoes
# 97          Khadims  Men Colourblocked Leather Slip-On Sneakers
# 98           Killer                        Men Slip-On Sneakers
# 99         Red Tape                           Men Walking Shoes
#
#                            Price
# 0           Men Clarkin Sneakers
# 1                   Men Sneakers
# 2              Men Walking Shoes
# 3     Men Colourblocked Sneakers
# 4   Men Printed Slip-On Sneakers
# ..                           ...
# 95                      Rs. 7499
# 96     Rs. 1324Rs. 5299(75% OFF)
# 97                      Rs. 2799
# 98      Rs. 699Rs. 1999(65% OFF)
# 99     Rs. 1349Rs. 5399(75% OFF)
#
# [100 rows x 3 columns]

# %% [markdown]
# # Question 7

# %%
driver.get('http://www.myntra.com/shoes')

# %%
bshoes=driver.find_element(By.CLASS_NAME,"desktop-searchBar")
bshoes.send_keys('Black_Shoes')

# %%
search=driver.find_element(By.CLASS_NAME,"desktop-submit")
search.click()

# %%
bshoes_name=[]
black_desp=[]
bprice_num=[]

# %%
bshoes_tags=driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
for i in bshoes_tags[0:100]:
    bshoes=i.text
    bshoes_name.append(bshoes)
    
black_tags=driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
for i in black_tags[0:100]:
    black=i.text
    black_desp.append(black)
    
bprice_tags=driver.find_elements(By.XPATH,'//div[@class="product-price"]')
for i in bprice_tags[0:100]:
    bprice=i.text
    bprice_num.append(bprice)

# %%
print(len(bshoes_name),len(black_desp),len(bprice_num))
# Out:
# 50 50 50

# %%
df=pd.DataFrame({'Black':bshoes,'Description':black_desp,'Price':bprice_num})
df
# Out:
#    Black                     Description                        Price
# 0   Xtep       Men Go Walk Walking Shoes                     Rs. 7499
# 1   Xtep     Unisex MAPF1 Drift Sneakers                     Rs. 8999
# 2   Xtep  Men JORDAN LOW Basketball Shoe                    Rs. 12795
# 3   Xtep      Men Response Super 3.0 Run                     Rs. 8999
# 4   Xtep               Men Running Shoes                     Rs. 7495
# 5   Xtep  Men HOVR SonicSE Running Shoes                     Rs. 9999
# 6   Xtep        Men ENIGMA Running Shoes    Rs. 8074Rs. 9499(15% OFF)
# 7   Xtep  Men ChargedEscape 3 BL Running                     Rs. 8999
# 8   Xtep  Men REACT MILER 3 Running Shoe                    Rs. 10495
# 9   Xtep      Unisex 3ZER0 IV Basketball                     Rs. 8999
# 10  Xtep       Men GO WALK - TERRA Shoes                     Rs. 9999
# 11  Xtep  Men HOVR SonicSE Running Shoes                     Rs. 9999
# 12  Xtep       GO WALK STRETCH FIT Shoes                     Rs. 7499
# 13  Xtep   Men Solid Retropy F2 Sneakers                     Rs. 8999
# 14  Xtep  Men HOVR Sonic SE Running Shoe    Rs. 8499Rs. 9999(15% OFF)
# 15  Xtep        Men ZX 22 BOOST Sneakers                    Rs. 11999
# 16  Xtep       Men Woven Nmd_R1 Sneakers                    Rs. 12999
# 17  Xtep      Men M Nitro Running Shoess   Rs. 8449Rs. 12999(35% OFF)
# 18  Xtep         Men Deviate Nitro Shoes  Rs. 10499Rs. 14999(30% OFF)
# 19  Xtep            Men Air Max Sneakers     Rs. 7880Rs. 8295(5% OFF)
# 20  Xtep      Men KD 15 Basketball Shoes                    Rs. 13995
# 21  Xtep      Men SPORTY RUNNER Sneakers                     Rs. 7999
# 22  Xtep            Men Leather Sneakers                     Rs. 7999
# 23  Xtep   Women Super 3.0 Running Shoes                     Rs. 8999
# 24  Xtep   Women Courtjam Control Tennis                     Rs. 7999
# 25  Xtep      Men Response Super 3.0 Run                     Rs. 8999
# 26  Xtep      Men Liberate Running Shoes   Rs. 9349Rs. 10999(15% OFF)
# 27  Xtep       Men Renew 3 Running Shoes                     Rs. 7495
# 28  Xtep  Men HOVR SonicSE Running Shoes                     Rs. 9999
# 29  Xtep    Men Kyrie Flytrap Basketball                     Rs. 8495
# 30  Xtep       Men Magnify Nitro Running   Rs. 8449Rs. 12999(35% OFF)
# 31  Xtep   Women FluidFlow 2.0 Run Shoes    Rs. 7199Rs. 7999(10% OFF)
# 32  Xtep    Eternity Nitro Running Shoes  Rs. 11049Rs. 12999(15% OFF)
# 33  Xtep      Unisex Woven EQT93 Sandals                     Rs. 9999
# 34  Xtep   Unisex Curry Basketball Shoes                    Rs. 10999
# 35  Xtep       Men CourtJam Control Clay                     Rs. 7999
# 36  Xtep     Men Terrex Soulstride Trail                     Rs. 7999
# 37  Xtep     Men Fast-Trac Nitro Running   Rs. 8799Rs. 10999(20% OFF)
# 38  Xtep    Unisex X9000L3 Running Shoes                    Rs. 11999
# 39  Xtep  Men Nitro 2 WIDE Running Shoes   Rs. 9599Rs. 11999(20% OFF)
# 40  Xtep               Men Walking Shoes                     Rs. 8999
# 41  Xtep   Men FloatrideEnergy4Adventure                    Rs. 12999
# 42  Xtep     Unisex KING Pro 21 Football    Rs. 7199Rs. 9999(28% OFF)
# 43  Xtep         Men FREE RUN 2 Sneakers     Rs. 9210Rs. 9695(5% OFF)
# 44  Xtep  Men GO FLEX 2-COMPLETION Shoes                     Rs. 7499
# 45  Xtep     Men Sky Vault Walking Shoes                     Rs. 8999
# 46  Xtep                Men Sports Shoes                     Rs. 7999
# 47  Xtep    Men Textured Leather Loafers                     Rs. 7990
# 48  Xtep        Women Superstar Sneakers    Rs. 8999Rs. 9999(10% OFF)
# 49  Xtep         Men Skateboarding Shoes                     Rs. 8599

# %% [markdown]
# # Question 8

# %%
driver.get('https://www.amazon.in/')

# %%
laptop=driver.find_element(By.CLASS_NAME,"nav-input nav-progressive-attribute"")
laptop.send_keys('Laptop')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\RAJATS~1\AppData\Local\Temp/ipykernel_16116/959356288.py in <module>
# ----> 1 laptop=driver.find_element(By.CLASS_NAME,"nav-input nav-progressive-attribute")
#       2 laptop.send_keys('Laptop')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     853             value = '[name="%s"]' % value
#     854
# --> 855         return self.execute(Command.FIND_ELEMENT, {
#     856             'using': by,
#     857             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     426         response = self.command_executor.execute(driver_command, params)
#     427         if response:
# --> 428             self.error_handler.check_response(response)
#     429             response['value'] = self._unwrap_value(
#     430                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".nav-input nav-progressive-attribute"}
#   (Session info: chrome=106.0.5249.91)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00B5DF13+2219795]
# 	Ordinal0 [0x00AF2841+1779777]
# 	Ordinal0 [0x00A0423D+803389]
# 	Ordinal0 [0x00A33025+995365]
# 	Ordinal0 [0x00A331EB+995819]
# 	Ordinal0 [0x00A60F52+1183570]
# 	Ordinal0 [0x00A4E844+1108036]
# 	Ordinal0 [0x00A5F192+1175954]
# 	Ordinal0 [0x00A4E616+1107478]
# 	Ordinal0 [0x00A27F89+950153]
# 	Ordinal0 [0x00A28F56+954198]
# 	GetHandleVerifier [0x00E52CB2+3040210]
# 	GetHandleVerifier [0x00E42BB4+2974420]
# 	GetHandleVerifier [0x00BF6A0A+565546]
# 	GetHandleVerifier [0x00BF5680+560544]
# 	Ordinal0 [0x00AF9A5C+1808988]
# 	Ordinal0 [0x00AFE3A8+1827752]
# 	Ordinal0 [0x00AFE495+1827989]
# 	Ordinal0 [0x00B080A4+1867940]
# 	BaseThreadInitThunk [0x76806359+25]
# 	RtlGetAppContainerNamedObjectPath [0x776687A4+228]
# 	RtlGetAppContainerNamedObjectPath [0x77668774+180]

# %%
title_name[]
ratings_d[]
price_amount[]

# %%
title_tags=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title_tags[0:10]:
    title=i.text
    title_name.append(title)
    
rating_tags=driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]')
for i in title_tags[0:10]:
    rating=i.text
    ratings_d.append(rating)
    
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tags[0:10]:
    price=i.text
    price_amount.append(price)

# %%
print(len(title_name),len(ratings_d),len(price_amount))

# %%
df=pd.DataFrame({'Title':title_name,'Rating':ratings_d,'Price':price_amount})
df

# %% [markdown]
# # Question 10

# %%
driver.get('http://www.ambitionbox.com/')

# %%
job=driver.find_element(By.CLASS_NAME,"tt-input")
job.send_keys('Data_Scientist')

# %%
company_name=[]
salary_record=[]
average_salary=[]
minimum_salary=[]
maximum_salary=[]
experience_required=[]

# %%
company_tags=driver.find_elements(By.XPATH,'//div[@class="name"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
salary_tags=driver.find_elements(By.XPATH,'//span[@class="salary-datapoints"]')
for i in salary_tags[0:10]:
    salary=i.text
    salary_record.append(salary)
    
average_tags=driver.find_elements(By.XPATH,'//p[@class="averageCtc"]')
for i in average_tags[0:10]:
    average=i.text
    average_salary.append(average)
    
minimum_tags=driver.find_elements(By.XPATH,'//div[@class="value body-medium"]')
for i in minimum_tags[0:10]:
    minimum=i.text
    minimum_salary.append(minimum)
    
maximum_tags=driver.find_elements(By.XPATH,'//div[@class="value body-medium"]')
for i in maximum_tags[1:11:1]:
    maximum=i.text
    maximum_salary.append(maximum)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class="sbold-list-header"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(company_name),len(salary_record),len(average_salary),len(minimum_salary),len(maximum_salary),len(experience_required))
# Out:
# 50 50 50 50 49 50

# %%
df=pd.DataFrame({'Company':company_name,'Salary':salary_record,'Average':average_salary,'Minimum':minimum_salary,'Maximum':maximum_salary,'Experience':experience_required})
df
# Out:
#                                      Company           Salary  Average  \
# 0                 TCS\nData Scientist Salary  (1.2k Salaries)  ₹ 21.0L
# 1           Accenture\nData Scientist Salary   (731 Salaries)   ₹ 4.4L
# 2                 IBM\nData Scientist Salary   (548 Salaries)   ₹ 8.5L
# 3           Cognizant\nData Scientist Salary   (456 Salaries)
# 4           Capgemini\nData Scientist Salary   (401 Salaries)
# 5             Infosys\nData Scientist Salary   (339 Salaries)
# 6               Wipro\nData Scientist Salary   (318 Salaries)
# 7       Tech Mahindra\nData Scientist Salary   (311 Salaries)
# 8              Amazon\nData Scientist Salary   (240 Salaries)
# 9   Fractal Analytics\nData Scientist Salary   (228 Salaries)   ₹ 7.5L
# 10                TCS\nData Scientist Salary  (1.2k Salaries)  ₹ 21.0L
# 11          Accenture\nData Scientist Salary   (731 Salaries)   ₹ 4.4L
# 12                IBM\nData Scientist Salary   (548 Salaries)   ₹ 8.5L
# 13          Cognizant\nData Scientist Salary   (456 Salaries)
# 14          Capgemini\nData Scientist Salary   (401 Salaries)
# 15            Infosys\nData Scientist Salary   (339 Salaries)
# 16              Wipro\nData Scientist Salary   (318 Salaries)
# 17      Tech Mahindra\nData Scientist Salary   (311 Salaries)
# 18             Amazon\nData Scientist Salary   (240 Salaries)
# 19  Fractal Analytics\nData Scientist Salary   (228 Salaries)   ₹ 7.5L
# 20                TCS\nData Scientist Salary  (1.2k Salaries)  ₹ 21.0L
# 21          Accenture\nData Scientist Salary   (731 Salaries)   ₹ 4.4L
# 22                IBM\nData Scientist Salary   (548 Salaries)   ₹ 8.5L
# 23          Cognizant\nData Scientist Salary   (456 Salaries)
# 24          Capgemini\nData Scientist Salary   (401 Salaries)
# 25            Infosys\nData Scientist Salary   (339 Salaries)
# 26              Wipro\nData Scientist Salary   (318 Salaries)
# 27      Tech Mahindra\nData Scientist Salary   (311 Salaries)
# 28             Amazon\nData Scientist Salary   (240 Salaries)
# 29  Fractal Analytics\nData Scientist Salary   (228 Salaries)   ₹ 7.5L
#
#     Minimum  Maximum                   Experience
# 0    ₹ 9.5L   ₹ 9.5L             Sort By: Popular
# 1   ₹ 44.2L  ₹ 44.2L  2-9 yrs exp (1.2k Salaries)
# 2    ₹ 1.8L   ₹ 1.8L   2-9 yrs exp (731 Salaries)
# 3   ₹ 12.2L  ₹ 12.2L  2-11 yrs exp (548 Salaries)
# 4    ₹ 3.2L   ₹ 3.2L  2-10 yrs exp (456 Salaries)
# 5   ₹ 23.8L  ₹ 23.8L   2-8 yrs exp (401 Salaries)
# 6                      2-7 yrs exp (339 Salaries)
# 7                      2-9 yrs exp (318 Salaries)
# 8                     2-12 yrs exp (311 Salaries)
# 9                     1-10 yrs exp (240 Salaries)
# 10   ₹ 9.5L   ₹ 9.5L             Sort By: Popular
# 11  ₹ 44.2L  ₹ 44.2L  2-9 yrs exp (1.2k Salaries)
# 12   ₹ 1.8L   ₹ 1.8L   2-9 yrs exp (731 Salaries)
# 13  ₹ 12.2L  ₹ 12.2L  2-11 yrs exp (548 Salaries)
# 14   ₹ 3.2L   ₹ 3.2L  2-10 yrs exp (456 Salaries)
# 15  ₹ 23.8L  ₹ 23.8L   2-8 yrs exp (401 Salaries)
# 16                     2-7 yrs exp (339 Salaries)
# 17                     2-9 yrs exp (318 Salaries)
# 18                    2-12 yrs exp (311 Salaries)
# 19                    1-10 yrs exp (240 Salaries)
# 20   ₹ 9.5L   ₹ 9.5L             Sort By: Popular
# 21  ₹ 44.2L  ₹ 44.2L  2-9 yrs exp (1.2k Salaries)
# 22   ₹ 1.8L   ₹ 1.8L   2-9 yrs exp (731 Salaries)
# 23  ₹ 12.2L  ₹ 12.2L  2-11 yrs exp (548 Salaries)
# 24   ₹ 3.2L   ₹ 3.2L  2-10 yrs exp (456 Salaries)
# 25  ₹ 23.8L  ₹ 23.8L   2-8 yrs exp (401 Salaries)
# 26                     2-7 yrs exp (339 Salaries)
# 27                     2-9 yrs exp (318 Salaries)
# 28                    2-12 yrs exp (311 Salaries)
# 29                    1-10 yrs exp (240 Salaries)

# %%
experience_tags=driver.find_elements(By.XPATH,'//div[@class="sbold-list-header"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(experience_required))
# Out:
# 30
